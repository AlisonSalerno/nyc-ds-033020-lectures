# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import matplotlib
# %matplotlib inline
#matplotlib notebook

# %%
data = pd.read_csv('CNN_School_Shooting_Data.csv')

# %%
data.head()
# Out:
#       LONCOD     LATCOD  CDCODE  year                            school  \
# 0 -75.584900  39.668100  1000.0  2009          William Penn High School
# 1 -87.617500  41.839900  1701.0  2009  Dunbar Vocational Career Academy
# 2 -90.165100  38.565700  1712.0  2009               Cahokia High School
# 3 -78.311800  35.831500  3713.0  2009             Zebulon Middle School
# 4 -83.113977  42.383593     NaN  2009               Central High School
#
#          city           state                          address  urbanrural  \
# 0  New Castle        Delaware                   713 E Basin Rd  suburbtown
# 1     Chicago        Illinois                   3000 S King Dr       urban
# 2     Cahokia        Illinois                     800 Range Ln  suburbtown
# 3     Zebulon  North Carolina  Halifax Road and New Oak Street  suburbtown
# 4     Detroit        Michigan                   2425 Tuxedo St       urban
#
#     race  killed  injured  victims       date           type       NCESSCH  \
# ...

# %%
data['year'].unique()
# Out:
# array([2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 17 columns):
# LONCOD        177 non-null float64
# LATCOD        177 non-null float64
# CDCODE        169 non-null float64
# year          180 non-null int64
# school        180 non-null object
# city          180 non-null object
# state         180 non-null object
# address       180 non-null object
# urbanrural    177 non-null object
# race          173 non-null object
# killed        180 non-null int64
# injured       180 non-null int64
# victims       180 non-null int64
# date          180 non-null object
# type          180 non-null object
# NCESSCH       175 non-null float64
# time          174 non-null object
# dtypes: float64(4), int64(4), object(9)
# memory usage: 24.0+ KB

# %%
per_year=data.sort_values(by='year',ascending=True)

# %%
counts=per_year.year.value_counts()

# %%
shootings=per_year['year'].unique()

# %%
df=pd.DataFrame(counts,shootings)

df.rename(columns={'year':'total shootings'},inplace=True)

# %%
df
# Out:
#       total shootings
# 2009               13
# 2010                8
# 2011               12
# 2012                7
# 2013               12
# 2014               20
# 2015               17
# 2016               35
# 2017               27
# 2018               29

# %%
#fig=plt.figure()
df.plot(kind='bar')
#fig1=df.plot(kind='bar',legend=False)
df.set_title("2009-2018 US school shootings")
df.set_ylabel('# of shootings')
df.set_xlabel('Year')

#df.plot(kind='bar')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-324-5ca8f51939ef> in <module>
#       2 df.plot(kind='bar')
#       3 #fig1=df.plot(kind='bar',legend=False)
# ----> 4 df.set_title("2009-2018 US school shootings")
#       5 df.set_ylabel('# of shootings')
#       6 df.set_xlabel('Year')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'set_title'

# %%
#Writer = animation.writers['ffmpeg']
#writer = Writer(fps=20, metadata=dict(artist='Me'), bitrate=1800)

# %%
def animate(i):
    data = df.iloc[:int(i+1)] #select data range
    #fig2=data.plot(kind='bar',legend=False)
    p = sns.barplot(y=data['year'], x=data.index, data=data, color="r")

# %%
sns.barplot(y=df['total shootings'], x=df.index, data=data, color="r")


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
ani=matplotlib.animation.FuncAnimation(fig, animate, frames=9)
plt.show()

# %%
#ani.save('Shootings.mp4')
# %matplotlib qt
ani

plt.show()

# %%
avocado=pd.read_csv('Avocado 2.csv')
avocado.groupby('year')['AveragePrice'].mean()
# Out:
# year
# 2015    1.375590
# 2016    1.338640
# 2017    1.519468
# 2018    1.355019
# 2019    1.412741
# Name: AveragePrice, dtype: float64

# %%
#%matplotlib qt
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.animation
import seaborn as sns 



fig, ax = plt.subplots()

plt.title("2009-2018 US school shootings")
plt.ylabel('# of shootings')
plt.xlabel('Year')



def animate(i):
    data = df.iloc[:int(i+1)] #select data range
    graph = sns.barplot(y=data['total shootings'], x=data.index, data=data, color="blue")

ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(data.index),interval=700,repeat=True)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
from matplotlib.animation import FuncAnimation, PillowWriter
ani.save('basic_animation.mp4',writer=PillowWriter(fps=30))
# Out:
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2063             try:
# -> 2064                 format = EXTENSION[ext]
#    2065             except KeyError:
#
# KeyError: '.mp4'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-328-ccf2330547e1> in <module>
#       1 from matplotlib.animation import FuncAnimation, PillowWriter
# ----> 2 ani.save('basic_animation.mp4',writer=PillowWriter(fps=30))
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
# ...

# %%
# %matplotlib qt
import matplotlib.pyplot as plt
import matplotlib.animation
import numpy as np

t = np.linspace(0,2*np.pi)
x = np.sin(t)

fig, ax = plt.subplots()
l, = ax.plot([0,2*np.pi],[-1,1])

animate = lambda i: l.set_data(t[:i], x[:i])

ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(t))

plt.show()
# Out:
# ...
# <img src="data:image/png;base64,..." width="432">
